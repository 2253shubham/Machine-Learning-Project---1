# %%
# %pwd
# Out:
# '/content'

# %%
# %cd /content/drive/MyDrive/Github/Machine_Learning_Project_1/
# Out:
# /content/drive/MyDrive/Github/Machine_Learning_Project_1

# %%
# %ls
# Out:
# LICENSE  n1.ipynb  README.md

# %%
import numpy as np
a = 2 + 3
print(np.add(a,2))
# Out:
# 7
